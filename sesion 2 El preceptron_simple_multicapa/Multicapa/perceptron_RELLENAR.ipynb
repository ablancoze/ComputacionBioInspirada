# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
# FUNCIONES DE ACTIVACION
class function(object):
    def __init__(self,funcion,derivative=None):
        self.F=funcion
        self.D=derivative

# %%
#funciones de activación

def cross_entropy(predictions, targets, epsilon=1e-12):
    predictions = np.clip(predictions, epsilon, 1. - epsilon)
    N = predictions.shape[0]
    ce = -np.sum(targets*np.log(predictions+1e-9))/N
    return ce



lineal=function(funcion=lambda x:x,derivative=lambda x:1)
sigm=function(funcion=lambda x: 1 / (1 + np.e ** (-x)),derivative=lambda x: x * (1 - x))
tanh=function(funcion=lambda x: 2 / (1 + np.e ** (2*x))-1,derivative=lambda x:1-((2 / (1 + np.e ** (2*x)))-1)**2)

softmax=function(funcion=lambda x: np.exp(x) / np.sum(np.exp(x), axis=0), derivative=lambda x:x*(1-x))
relu=function(funcion=lambda x: np.maximum(0, x) ,derivative=lambda x: np.where(x<=0,0,1))

# funciones de coste
l2_cost=function(funcion=lambda Yp, Yr: np.mean((Yp - Yr) ** 2) ,derivative=lambda Yp, Yr: (Yp - Yr))

_x = np.linspace(-10, 10, 100)

plt.plot(_x, softmax.F(_x),"tab:blue")

# %%
# CLASE DE LA CAPA DE LA RED
from IPython.display import clear_output
import time

class neural_layer():
 
  def __init__(self, n_conn, n_neur, act_f):
    self.act = act_f
    self.b = np.random.rand(1, n_neur)      * 2 - 1
    self.W = np.random.rand(n_conn, n_neur) * 2 - 1
    
# creación de una red neuronal según topologia
def create_nn(topology):
  nn = []
  for l, layer in enumerate(topology[:-1]):
    nn.append(neural_layer(topology[l][0], topology[l+1][0], topology[l][1]))
  return nn
    
# fucnción de predicción (fordware pass)    
def predict(neural_net, X):
  
  out = [(None, X)] #primer data necesario
  
  # Forward pass
  for l, layer in enumerate(neural_net):
    z = out[-1][1] @ neural_net[l].W + neural_net[l].b
    a = neural_net[l].act.F(z)
    out.append((z, a))
  return out[-1][1]
  
# función retropropagación del error
def backward_pass(neural_net, X, Y, l2_cost, lr=0.5,momentun=1,batch_size=1):
  sx=np.shape(X)
  sy=np.shape(Y)
  X=X.reshape(1,sx[0])
  Y=Y.reshape(1,sy[0])
  print (Y)
  print (X)
  out = [(None, X)] #primer data necesario
  # Forward pass
  for l, layer in enumerate(neural_net):
    z = out[-1][1] @ neural_net[l].W + neural_net[l].b
    a = neural_net[l].act.F(z)
    out.append((z, a))
  acc=np.round(a)==Y
  # Backward pass 
  deltas = []
  for l in reversed(range(0, len(neural_net))):
    z = out[l+1][0]
    a = out[l+1][1]
    if l == len(neural_net) - 1:
      deltas.insert(0, l2_cost.D(a, Y) * neural_net[l].act.D(a))
    else:
      deltas.insert(0, deltas[0] @ _W.T * neural_net[l].act.D(a))
    _W = neural_net[l].W
 
    # Gradient descent
    neural_net[l].b = neural_net[l].b - np.mean(deltas[0], axis=0, keepdims=True) * lr   
    neural_net[l].W = neural_net[l].W - out[l][1].T @ deltas[0] * lr
  return out[-1][1],acc


# función de entrenamiento de la red
def train(neural_net,X,Y,l2_cost,lr=0.5,epoch=1000,momentun=1,batch_size=1):
    loss = []
    ACC =[]
    for i in range(epoch):
        account=0
        # Entrenemos a la red!
        for j in range(len(X)):
            pY,acc = backward_pass(neural_net, X[j,:], Y[j,:], l2_cost, lr,momentun,batch_size)
            if acc.all():
                account+=1
        print("Epoch={}, Loss={} Accuracy={}".format(i,round(l2_cost.F(pY,Y[j,:]),15),round(account/len(Y),3)),end="")
        clear_output(wait=True)
        ACC.append(account/len(Y))    
        loss.append(l2_cost.F(pY,Y[j,:]))
     
    return loss,ACC

# %% [markdown]
# # Realiza un ejemplo de clasificación y regresión
# Hay varios datasets dentro del directorio o si lo prefieres puede bajar más de esta web:
# https://www.mldata.io/datasets/
#
# Debes realizar usando este perceptrón un ajuste de una red para un dataset de clasificación y otro de regresión
#
# Ajusta los vectores de entrada y normaliza los datos a flotantes...
# Guarda algunos valores separados para luego probar tu red
# Entrena la red usando varias topologia no muy complicadas.
# No te preocupes si el error no es muy bajo.
# Indica cómo crees que se comporta la red que has definido

# %%
#carga datos
import csv
X=[]
Y=[]
with open('iris.csv') as csvfile: 
    reader = csv.reader(csvfile)
    for row in reader:
        s=row[0].split(",")
        R=[float(s[0]),float(s[1]),float(s[2]),float(s[3])]
        X.append(R)
        if s[4]=='"Setosa"':
            Y.append([1.,0.,0.])
            
        if s[4]=='"Versicolor"':
            Y.append([0.,1.,0.])
        
        if s[4]=='"Virginica"':
            Y.append([0.,0.,1.])
            
X=np.array(X)
Y=np.array(Y)
print (np.shape(X))
print (np.shape(Y))
#gráfica de datos
import matplotlib.pyplot as plt

plt.figure()
plt.plot(X[:,0], X[:,1], color="r", marker='.',linestyle="none")
plt.show()
# Out:
# (150, 4)
# (150, 3)

# %%
# definicion de la red
topology=[(4,sigm),(8,sigm),(3,sigm)]
myred=create_nn(topology)
epoch = 350
lr=0.04
loss=[]
accuracy=[]
loss,accuracy=train(myred,X,Y,l2_cost,lr,epoch)
# Out:
# [[1. 0. 0.]]
# [[5.1 3.5 1.4 0.2]]
# [[1. 0. 0.]]
# [[4.9 3.  1.4 0.2]]
# [[1. 0. 0.]]
# [[4.7 3.2 1.3 0.2]]
# [[1. 0. 0.]]
# [[4.6 3.1 1.5 0.2]]
# [[1. 0. 0.]]
# [[5.  3.6 1.4 0.2]]
# [[1. 0. 0.]]
# [[5.4 3.9 1.7 0.4]]
# [[1. 0. 0.]]
# [[4.6 3.4 1.4 0.3]]
# [[1. 0. 0.]]
# [[5.  3.4 1.5 0.2]]
# [[1. 0. 0.]]
# [[4.4 2.9 1.4 0.2]]
# [[1. 0. 0.]]
# [[4.9 3.1 1.5 0.1]]
# [[1. 0. 0.]]
# [[5.4 3.7 1.5 0.2]]
# [[1. 0. 0.]]
# [[4.8 3.4 1.6 0.2]]
# [[1. 0. 0.]]
# [[4.8 3.  1.4 0.1]]
# [[1. 0. 0.]]
# [[4.3 3.  1.1 0.1]]
# [[1. 0. 0.]]
# [[5.8 4.  1.2 0.2]]
# [[1. 0. 0.]]
# [[5.7 4.4 1.5 0.4]]
# [[1. 0. 0.]]
# [[5.4 3.9 1.3 0.4]]
# [[1. 0. 0.]]
# [[5.1 3.5 1.4 0.3]]
# [[1. 0. 0.]]
# [[5.7 3.8 1.7 0.3]]
# [[7.2 3.6 6.1 2.5]]
# [[0. 0. 1.]]
# [[6.5 3.2 5.1 2. ]]
# [[0. 0. 1.]]
# [[6.4 2.7 5.3 1.9]]
# [[0. 0. 1.]]
# [[6.8 3.  5.5 2.1]]
# [[0. 0. 1.]]
# [[5.7 2.5 5.  2. ]]
# [[0. 0. 1.]]
# [[5.8 2.8 5.1 2.4]]
# [[0. 0. 1.]]
# [[6.4 3.2 5.3 2.3]]
# [[0. 0. 1.]]
# [[6.5 3.  5.5 1.8]]
# [[0. 0. 1.]]
# [[7.7 3.8 6.7 2.2]]
# [[0. 0. 1.]]
# [[7.7 2.6 6.9 2.3]]
# [[0. 0. 1.]]
# [[6.  2.2 5.  1.5]]
# [[0. 0. 1.]]
# [[6.9 3.2 5.7 2.3]]
# [[0. 0. 1.]]
# [[5.6 2.8 4.9 2. ]]
# [[0. 0. 1.]]
# [[7.7 2.8 6.7 2. ]]
# [[0. 0. 1.]]
# [[6.3 2.7 4.9 1.8]]
# [[0. 0. 1.]]
# [[6.7 3.3 5.7 2.1]]
# [[0. 0. 1.]]
# [[7.2 3.2 6.  1.8]]
# [[0. 0. 1.]]
# [[6.2 2.8 4.8 1.8]]
# [[0. 0. 1.]]
# [[6.1 3.  4.9 1.8]]
# [[0. 0. 1.]]
# [[6.4 2.8 5.6 2.1]]
# [[0. 0. 1.]]
# [[7.2 3.  5.8 1.6]]
# [[0. 0. 1.]]
# [[7.4 2.8 6.1 1.9]]
# [[0. 0. 1.]]
# [[7.9 3.8 6.4 2. ]]
# [[0. 0. 1.]]
# [[6.4 2.8 5.6 2.2]]
# [[0. 0. 1.]]
# [[6.3 2.8 5.1 1.5]]
# [[0. 0. 1.]]
# [[6.1 2.6 5.6 1.4]]
# [[0. 0. 1.]]
# [[7.7 3.  6.1 2.3]]
# [[0. 0. 1.]]
# [[6.3 3.4 5.6 2.4]]
# [[0. 0. 1.]]
# [[6.4 3.1 5.5 1.8]]
# [[0. 0. 1.]]
# [[6.  3.  4.8 1.8]]
# [[0. 0. 1.]]
# [[6.9 3.1 5.4 2.1]]
# [[0. 0. 1.]]
# [[6.7 3.1 5.6 2.4]]
# [[0. 0. 1.]]
# [[6.9 3.1 5.1 2.3]]
# [[0. 0. 1.]]
# [[5.8 2.7 5.1 1.9]]
# [[0. 0. 1.]]
# [[6.8 3.2 5.9 2.3]]
# [[0. 0. 1.]]
# [[6.7 3.3 5.7 2.5]]
# [[0. 0. 1.]]
# [[6.7 3.  5.2 2.3]]
# [[0. 0. 1.]]
# [[6.3 2.5 5.  1.9]]
# [[0. 0. 1.]]
# [[6.5 3.  5.2 2. ]]
# [[0. 0. 1.]]
# [[6.2 3.4 5.4 2.3]]
# [[0. 0. 1.]]
# [[5.9 3.  5.1 1.8]]
# Epoch=18, Loss=0.04739673730041 Accuracy=0.773
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-427dce413d0a> in <module>
#       6 loss=[]
#       7 accuracy=[]
# ----> 8 loss,accuracy=train(myred,X,Y,l2_cost,lr,epoch)
#
# <ipython-input-33-35555b659811> in train(neural_net, X, Y, l2_cost, lr, epoch, momentun, batch_size)
#      73                 account+=1
#      74         print("Epoch={}, Loss={} Accuracy={}".format(i,round(l2_cost.F(pY,Y[j,:]),15),round(account/len(Y),3)),end="")
# ---> 75         clear_output(wait=True)
#      76         ACC.append(account/len(Y))
#      77         loss.append(l2_cost.F(pY,Y[j,:]))
#
# ~/Escritorio/UNI/Clase/CompuBioInspirada/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in clear_output(wait)
#    1425     from IPython.core.interactiveshell import InteractiveShell
#    1426     if InteractiveShell.initialized():
# -> 1427         InteractiveShell.instance().display_pub.clear_output(wait)
#    1428     else:
#    1429         print('\033[2K\r', end='')
#
# ~/Escritorio/UNI/Clase/CompuBioInspirada/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py in clear_output(self, wait)
#     158         self.session.send(
#     159             self.pub_socket, u'clear_output', content,
# --> 160             parent=self.parent_header, ident=self.topic,
#     161         )
#     162
#
# ~/Escritorio/UNI/Clase/CompuBioInspirada/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     735         if self.adapt_version:
#     736             msg = adapt(msg, self.adapt_version)
# --> 737         to_send = self.serialize(msg, ident)
#     738         to_send.extend(buffers)
#     739         longest = max([ len(s) for s in to_send ])
#
# ~/Escritorio/UNI/Clase/CompuBioInspirada/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in serialize(self, msg, ident)
#     648         to_send.append(DELIM)
#     649
# --> 650         signature = self.sign(real_message)
#     651         to_send.append(signature)
#     652
#
# ~/Escritorio/UNI/Clase/CompuBioInspirada/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in sign(self, msg_list)
#     594         for m in msg_list:
#     595             h.update(m)
# --> 596         return str_to_bytes(h.hexdigest())
#     597
#     598     def serialize(self, msg, ident=None):
#
# ~/Escritorio/UNI/Clase/CompuBioInspirada/anaconda3/lib/python3.7/hmac.py in hexdigest(self)
#     137         """Like digest(), but returns a string of hexadecimal digits instead.
#     138         """
# --> 139         h = self._current()
#     140         return h.hexdigest()
#     141
#
# ~/Escritorio/UNI/Clase/CompuBioInspirada/anaconda3/lib/python3.7/hmac.py in _current(self)
#     120         To be used only internally with digest() and hexdigest().
#     121         """
# --> 122         h = self.outer.copy()
#     123         h.update(self.inner.digest())
#     124         return h
#
# KeyboardInterrupt:

# %%
plt.plot(range(len(loss)), loss)
#plt.axis([0, epoch, 0, 1])
plt.ylabel("loss function")
plt.xlabel("EPOCH NUMBER")
plt.show()

plt.plot(range(len(accuracy)), accuracy)
#plt.axis([0, epoch, 0, 1])
plt.ylabel("accuracy function")
plt.xlabel("EPOCH NUMBER")
plt.show()

# %%
# VISUALIZACIÓN Y TEST
#  ahora podemos interrogar. el primer valor es el bias
for i in range(len(X)):
    print("predecir ",X[i],"--",Y[i]," predict: ",np.round(predict(myred,X[i])))
# Out:
# predecir  [5.1 3.5 1.4 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.9 3.  1.4 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.7 3.2 1.3 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.6 3.1 1.5 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.  3.6 1.4 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.4 3.9 1.7 0.4] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.6 3.4 1.4 0.3] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.  3.4 1.5 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.4 2.9 1.4 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.9 3.1 1.5 0.1] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.4 3.7 1.5 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.8 3.4 1.6 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.8 3.  1.4 0.1] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.3 3.  1.1 0.1] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.8 4.  1.2 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.7 4.4 1.5 0.4] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.4 3.9 1.3 0.4] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.1 3.5 1.4 0.3] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.7 3.8 1.7 0.3] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.1 3.8 1.5 0.3] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.4 3.4 1.7 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.1 3.7 1.5 0.4] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.6 3.6 1.  0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.1 3.3 1.7 0.5] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.8 3.4 1.9 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.  3.  1.6 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.  3.4 1.6 0.4] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.2 3.5 1.5 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.2 3.4 1.4 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.7 3.2 1.6 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.8 3.1 1.6 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.4 3.4 1.5 0.4] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.2 4.1 1.5 0.1] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.5 4.2 1.4 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.9 3.1 1.5 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.  3.2 1.2 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.5 3.5 1.3 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.9 3.6 1.4 0.1] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.4 3.  1.3 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.1 3.4 1.5 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.  3.5 1.3 0.3] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.5 2.3 1.3 0.3] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.4 3.2 1.3 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.  3.5 1.6 0.6] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.1 3.8 1.9 0.4] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.8 3.  1.4 0.3] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.1 3.8 1.6 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [4.6 3.2 1.4 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.3 3.7 1.5 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [5.  3.3 1.4 0.2] -- [1. 0. 0.]  predict:  [[1. 0. 0.]]
# predecir  [7.  3.2 4.7 1.4] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.4 3.2 4.5 1.5] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.9 3.1 4.9 1.5] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.5 2.3 4.  1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.5 2.8 4.6 1.5] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.7 2.8 4.5 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.3 3.3 4.7 1.6] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [4.9 2.4 3.3 1. ] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.6 2.9 4.6 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.2 2.7 3.9 1.4] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.  2.  3.5 1. ] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.9 3.  4.2 1.5] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.  2.2 4.  1. ] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.1 2.9 4.7 1.4] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.6 2.9 3.6 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.7 3.1 4.4 1.4] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.6 3.  4.5 1.5] -- [0. 1. 0.]  predict:  [[0. 0. 1.]]
# predecir  [5.8 2.7 4.1 1. ] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.2 2.2 4.5 1.5] -- [0. 1. 0.]  predict:  [[0. 0. 1.]]
# predecir  [5.6 2.5 3.9 1.1] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.9 3.2 4.8 1.8] -- [0. 1. 0.]  predict:  [[0. 0. 1.]]
# predecir  [6.1 2.8 4.  1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.3 2.5 4.9 1.5] -- [0. 1. 0.]  predict:  [[0. 0. 1.]]
# predecir  [6.1 2.8 4.7 1.2] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.4 2.9 4.3 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.6 3.  4.4 1.4] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.8 2.8 4.8 1.4] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.7 3.  5.  1.7] -- [0. 1. 0.]  predict:  [[0. 0. 0.]]
# predecir  [6.  2.9 4.5 1.5] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.7 2.6 3.5 1. ] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.5 2.4 3.8 1.1] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.5 2.4 3.7 1. ] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.8 2.7 3.9 1.2] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.  2.7 5.1 1.6] -- [0. 1. 0.]  predict:  [[0. 0. 1.]]
# predecir  [5.4 3.  4.5 1.5] -- [0. 1. 0.]  predict:  [[0. 0. 1.]]
# predecir  [6.  3.4 4.5 1.6] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.7 3.1 4.7 1.5] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.3 2.3 4.4 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.6 3.  4.1 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.5 2.5 4.  1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.5 2.6 4.4 1.2] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.1 3.  4.6 1.4] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.8 2.6 4.  1.2] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.  2.3 3.3 1. ] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.6 2.7 4.2 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.7 3.  4.2 1.2] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.7 2.9 4.2 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.2 2.9 4.3 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.1 2.5 3.  1.1] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [5.7 2.8 4.1 1.3] -- [0. 1. 0.]  predict:  [[0. 1. 0.]]
# predecir  [6.3 3.3 6.  2.5] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [5.8 2.7 5.1 1.9] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.1 3.  5.9 2.1] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.3 2.9 5.6 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.5 3.  5.8 2.2] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.6 3.  6.6 2.1] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [4.9 2.5 4.5 1.7] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.3 2.9 6.3 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.7 2.5 5.8 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.2 3.6 6.1 2.5] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.5 3.2 5.1 2. ] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.4 2.7 5.3 1.9] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.8 3.  5.5 2.1] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [5.7 2.5 5.  2. ] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [5.8 2.8 5.1 2.4] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.4 3.2 5.3 2.3] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.5 3.  5.5 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.7 3.8 6.7 2.2] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.7 2.6 6.9 2.3] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.  2.2 5.  1.5] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.9 3.2 5.7 2.3] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [5.6 2.8 4.9 2. ] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.7 2.8 6.7 2. ] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.3 2.7 4.9 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.7 3.3 5.7 2.1] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.2 3.2 6.  1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.2 2.8 4.8 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.1 3.  4.9 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.4 2.8 5.6 2.1] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.2 3.  5.8 1.6] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.4 2.8 6.1 1.9] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.9 3.8 6.4 2. ] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.4 2.8 5.6 2.2] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.3 2.8 5.1 1.5] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.1 2.6 5.6 1.4] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [7.7 3.  6.1 2.3] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.3 3.4 5.6 2.4] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.4 3.1 5.5 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.  3.  4.8 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.9 3.1 5.4 2.1] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.7 3.1 5.6 2.4] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.9 3.1 5.1 2.3] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [5.8 2.7 5.1 1.9] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.8 3.2 5.9 2.3] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.7 3.3 5.7 2.5] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.7 3.  5.2 2.3] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.3 2.5 5.  1.9] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.5 3.  5.2 2. ] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [6.2 3.4 5.4 2.3] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
# predecir  [5.9 3.  5.1 1.8] -- [0. 0. 1.]  predict:  [[0. 0. 1.]]
